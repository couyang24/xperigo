# %% [markdown]
# # NYC Car Accident Analysis
# Chengran Ouyang
#
# 2019-04-24
#
# ## Step 1: Define the Problem
# Requirement:
#
# 1. Download the data, and load it in Pycharm and provide initial overview information.
#
# 2. Visualize the location of the car accidents.
#
# 3. Find out the insight from the dataset (i.e. Location/ Time of Day).
#
# 4. Take Weather Data into Consideration.
#
# This time, I would leverage the power of R and Python to perform the analysis and present the result via both Rmarkdown (R) and jupiter notebook (python). The analysis would be based on a standard data science framework and answer the questions above; however, I would extend the scope of the analysis to identify any unique insight as well as provide detailed explanation of my code.

# %% [markdown]
# ## Step 2: Gather the Data
#
# The dataset is acquired from Kaggle open datasource.The Data is available via [NYC hourly car accidents 2013-2016](https://www.kaggle.com/pavetr/nypdcollisions).

# %% [markdown]
# ## Step 3: Preprocess the Data
#
# ### 3.1 Dependencies
#
# #### 3.1.1 Required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
from IPython.display import display
from IPython.display import HTML
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
from branca.colormap import LinearColormap
import os

# %% [markdown]
# #### 3.1.2 Load Datasets

# %%
colli = pd.read_csv("input/NYPD_Motor_Vehicle_Collisions.csv")
# Out:
# C:\Users\Owen\AppData\Local\Programs\Python\Python37-32\lib\site-packages\IPython\core\interactiveshell.py:2705: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# #### 3.2 First Glimpse

# %% [markdown]
# #### 3.2.1 First and Last 5 Rows

# %%
display(colli.head(5))
display(colli.tail(5))
# Out:
#          DATE  TIME BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  08/04/2017  0:00  QUEENS    11436  40.666885 -73.790405
# 1  08/04/2017  0:00     NaN      NaN  40.719950 -74.008590
# 2  08/04/2017  0:00     NaN      NaN  40.718666 -73.963500
# 3  08/04/2017  0:00     NaN      NaN  40.754677 -73.975815
# 4  08/04/2017  0:00     NaN      NaN  40.818314 -73.836000
#
#                   LOCATION                    ON STREET NAME  \
# 0  (40.666885, -73.790405)  NORTH CONDUIT AVENUE
# 1    (40.71995, -74.00859)  HUDSON STREET
# 2    (40.718666, -73.9635)  KENT AVENUE
# 3  (40.754677, -73.975815)  PARK AVENUE
# 4     (40.818314, -73.836)                               NaN
#
#   CROSS STREET NAME OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0        149 STREET             NaN  ...                    Unspecified
# 1               NaN             NaN  ...           Unsafe Lane Changing
# 2               NaN             NaN  ...          Following Too Closely
# 3               NaN             NaN  ...                    Unspecified
# 4               NaN             NaN  ...                    Unspecified
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  UNIQUE KEY            VEHICLE TYPE CODE 1  \
# 0                            NaN     3725017              PASSENGER VEHICLE
# 1                            NaN     3725047                  PICK-UP TRUCK
# 2                            NaN     3725533  SPORT UTILITY / STATION WAGON
# 3                            NaN     3724870  SPORT UTILITY / STATION WAGON
# 4                            NaN     3725662              PASSENGER VEHICLE
#
#              VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 0              PASSENGER VEHICLE                  NaN                 NaN
# 1  SPORT UTILITY / STATION WAGON                  NaN                 NaN
# 2              PASSENGER VEHICLE                  NaN                 NaN
# 3                           TAXI                  NaN                 NaN
# 4              PASSENGER VEHICLE                  NaN                 NaN
#
#   VEHICLE TYPE CODE 5
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 29 columns]
#                DATE  TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 1089260  07/01/2012  9:45        NaN      NaN        NaN        NaN
# 1089261  07/01/2012  9:50  MANHATTAN    10019  40.766779 -73.996762
# 1089262  07/01/2012  9:50     QUEENS    11001  40.736245 -73.702966
# 1089263  07/01/2012  9:57  MANHATTAN    10065  40.765242 -73.957868
# 1089264  07/01/2012  9:59      BRONX    10452  40.835397 -73.920305
#
#                           LOCATION                    ON STREET NAME  \
# 1089260                        NaN                               NaN
# 1089261  (40.7667789, -73.9967618)  WEST SIDE HIGHWAY
# 1089262  (40.7362448, -73.7029656)  265 STREET
# 1089263  (40.7652424, -73.9578679)  1 AVENUE
# 1089264    (40.835397, -73.920305)  EAST 167 STREET
#
#                         CROSS STREET NAME OFF STREET NAME  ...  \
# 1089260                               NaN             NaN  ...
# 1089261  WEST 50 STREET                               NaN  ...
# 1089262  85 AVENUE                                    NaN  ...
# 1089263  EAST 68 STREET                               NaN  ...
# 1089264  GERARD AVENUE                                NaN  ...
#
#          CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 1089260                    Unspecified                            NaN
# 1089261                    Unspecified                            NaN
# 1089262                    Unspecified                            NaN
# 1089263                Other Vehicular                            NaN
# 1089264                    Unspecified                            NaN
#
#          CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 1089260                            NaN                            NaN
# 1089261                            NaN                            NaN
# 1089262                            NaN                            NaN
# 1089263                            NaN                            NaN
# 1089264                            NaN                            NaN
#
#          UNIQUE KEY  VEHICLE TYPE CODE 1            VEHICLE TYPE CODE 2  \
# 1089260     2896726    PASSENGER VEHICLE                        UNKNOWN
# 1089261       37635                  VAN  SPORT UTILITY / STATION WAGON
# 1089262      219395    PASSENGER VEHICLE  SPORT UTILITY / STATION WAGON
# 1089263       44907    PASSENGER VEHICLE                           TAXI
# 1089264       85154    PASSENGER VEHICLE  SPORT UTILITY / STATION WAGON
#
#          VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 1089260                  NaN                 NaN                 NaN
# 1089261                  NaN                 NaN                 NaN
# 1089262                  NaN                 NaN                 NaN
# 1089263                  NaN                 NaN                 NaN
# 1089264                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# #### 3.2.2 Structure

# %%
print('Number of rows: ', colli.shape[0])
print('Number of columns: ', colli.shape[1])
# Out:
# Number of rows:  1089265
# Number of columns:  29

# %% [markdown]
# #### 3.2.3 Data Range

# %%
colli.describe()
# Out:
#             LATITUDE      LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  882199.000000  882199.000000               1.089265e+06
# mean       40.721128     -73.924296               2.555733e-01
# std         0.301039       0.988562               6.565478e-01
# min         0.000000    -201.359990               0.000000e+00
# 25%        40.668960     -73.979025               0.000000e+00
# 50%        40.723305     -73.933153               0.000000e+00
# 75%        40.766351     -73.869289               0.000000e+00
# max        41.126150       0.000000               4.300000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              1.089265e+06                   1.089265e+06
# mean               1.198056e-03                   5.247300e-02
# std                3.632685e-02                   2.408481e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# 50%                0.000000e+00                   0.000000e+00
# 75%                0.000000e+00                   0.000000e+00
# max                5.000000e+00                   2.800000e+01
#
#        NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# count                  1.089265e+06               1.089265e+06
# mean                   6.646684e-04               2.047068e-02
# std                    2.602076e-02               1.449423e-01
# min                    0.000000e+00               0.000000e+00
# 25%                    0.000000e+00               0.000000e+00
# 50%                    0.000000e+00               0.000000e+00
# 75%                    0.000000e+00               0.000000e+00
# max                    2.000000e+00               4.000000e+00
#
#        NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# count              1.089265e+06                1.089265e+06
# mean               7.803427e-05                1.861668e-01
# std                8.833360e-03                6.263905e-01
# min                0.000000e+00                0.000000e+00
# 25%                0.000000e+00                0.000000e+00
# 50%                0.000000e+00                0.000000e+00
# 75%                0.000000e+00                0.000000e+00
# max                1.000000e+00                4.300000e+01
#
#        NUMBER OF MOTORIST KILLED    UNIQUE KEY
# count               1.089265e+06  1.089265e+06
# mean                4.535168e-04  2.200695e+06
# std                 2.366021e-02  1.519165e+06
# min                 0.000000e+00  2.200000e+01
# 25%                 0.000000e+00  2.742420e+05
# 50%                 0.000000e+00  3.180753e+06
# 75%                 0.000000e+00  3.453075e+06
# max                 5.000000e+00  3.726256e+06

# %% [markdown]
# #### 3.2.4 Data Type

# %%
colli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1089265 entries, 0 to 1089264
# Data columns (total 29 columns):
# DATE                             1089265 non-null object
# TIME                             1089265 non-null object
# BOROUGH                          792241 non-null object
# ZIP CODE                         792171 non-null object
# LATITUDE                         882199 non-null float64
# LONGITUDE                        882199 non-null float64
# LOCATION                         882199 non-null object
# ON STREET NAME                   892128 non-null object
# CROSS STREET NAME                854727 non-null object
# OFF STREET NAME                  160587 non-null object
# NUMBER OF PERSONS INJURED        1089265 non-null int64
# NUMBER OF PERSONS KILLED         1089265 non-null int64
# NUMBER OF PEDESTRIANS INJURED    1089265 non-null int64
# NUMBER OF PEDESTRIANS KILLED     1089265 non-null int64
# NUMBER OF CYCLIST INJURED        1089265 non-null int64
# NUMBER OF CYCLIST KILLED         1089265 non-null int64
# NUMBER OF MOTORIST INJURED       1089265 non-null int64
# NUMBER OF MOTORIST KILLED        1089265 non-null int64
# CONTRIBUTING FACTOR VEHICLE 1    1084674 non-null object
# CONTRIBUTING FACTOR VEHICLE 2    947827 non-null object
# CONTRIBUTING FACTOR VEHICLE 3    71026 non-null object
# CONTRIBUTING FACTOR VEHICLE 4    15318 non-null object
# CONTRIBUTING FACTOR VEHICLE 5    3759 non-null object
# UNIQUE KEY                       1089265 non-null int64
# VEHICLE TYPE CODE 1              1081881 non-null object
# VEHICLE TYPE CODE 2              922402 non-null object
# VEHICLE TYPE CODE 3              69043 non-null object
# VEHICLE TYPE CODE 4              14800 non-null object
# VEHICLE TYPE CODE 5              3650 non-null object
# dtypes: float64(2), int64(9), object(18)
# memory usage: 166.2+ MB

# %% [markdown]
# ### 3.3 Data Cleaning: Correcting, Completing, Creating, and Converting

# %% [markdown]
# As the data range section shows, some data entries for latitude and longitude are out of the scale and need to be corrected or removed.

# %%
rev_colli = colli[(colli['LATITUDE']>0)&(colli['LONGITUDE']>-75)&(colli['LONGITUDE']<-72)]

# %% [markdown]
# By removing the incorrect lat and lon information, I am examing the data again, which shows a more accurate scale.

# %%
display(rev_colli.describe())
# Out:
#             LATITUDE      LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  882110.000000  882110.000000              882110.000000
# mean       40.723205     -73.923021                   0.255677
# std         0.077699       0.086314                   0.653579
# min        40.498949     -74.742000                   0.000000
# 25%        40.668964     -73.979025                   0.000000
# 50%        40.723305     -73.933153                   0.000000
# 75%        40.766351     -73.869294                   0.000000
# max        41.126150     -73.700584                  43.000000
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count             882110.000000                  882110.000000
# mean                   0.001156                       0.055269
# std                    0.035836                       0.245425
# min                    0.000000                       0.000000
# 25%                    0.000000                       0.000000
# 50%                    0.000000                       0.000000
# 75%                    0.000000                       0.000000
# max                    5.000000                      28.000000
#
#        NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# count                 882110.000000              882110.000000
# mean                       0.000641                   0.021104
# std                        0.025479                   0.145954
# min                        0.000000                   0.000000
# 25%                        0.000000                   0.000000
# 50%                        0.000000                   0.000000
# 75%                        0.000000                   0.000000
# max                        2.000000                   4.000000
#
#        NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# count             882110.000000               882110.000000
# mean                   0.000077                    0.181391
# std                    0.008780                    0.617081
# min                    0.000000                    0.000000
# 25%                    0.000000                    0.000000
# 50%                    0.000000                    0.000000
# 75%                    0.000000                    0.000000
# max                    1.000000                   43.000000
#
#        NUMBER OF MOTORIST KILLED    UNIQUE KEY
# count              882110.000000  8.821100e+05
# mean                    0.000438  2.120917e+06
# std                     0.023517  1.540086e+06
# min                     0.000000  2.200000e+01
# 25%                     0.000000  2.508022e+05
# 50%                     0.000000  3.159300e+06
# 75%                     0.000000  3.421072e+06
# max                     5.000000  3.726256e+06

# %% [markdown]
# ## Step 4 Interactive Map

# %%
rev1_colli = rev_colli.sample(2000)

lat = rev1_colli['LATITUDE'].tolist()
lon = rev1_colli['LONGITUDE'].tolist()
locations = list(zip(lat, lon))

map1 = folium.Map(location=[40.723205, -73.923021], zoom_start=11.5)
#FastMarkerCluster(data=locations).add_to(map1)
#                 icon = folium.Icon(icon='car'))
marker_cluster = MarkerCluster().add_to(map1)

for point in range(len(locations)):
    folium.Marker(
        location=locations[point],
        #popup='Add popup text here.',
        icon=folium.Icon(color='red', icon='remove-sign'),
    ).add_to(marker_cluster)

map1.save("map1.html")
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Step 5 Sever Car Accidents

# %%
display(rev_colli[rev_colli['NUMBER OF MOTORIST INJURED']==43].iloc[:,0:10])
display(rev_colli[rev_colli['NUMBER OF MOTORIST INJURED']==43].iloc[:,10:20])
display(rev_colli[rev_colli['NUMBER OF MOTORIST INJURED']==43].iloc[:,20:29])
# Out:
#               DATE   TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 850220  09/09/2013  16:38  BROOKLYN    11213  40.679035 -73.938508
#
#                          LOCATION                    ON STREET NAME  \
# 850220  (40.6790346, -73.9385077)  HERKIMER STREET
#
#                        CROSS STREET NAME OFF STREET NAME
# 850220  ALBANY AVENUE                                NaN
#         NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 850220                         43                         0
#
#         NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# 850220                              0                             0
#
#         NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# 850220                          0                         0
#
#         NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  \
# 850220                          43                          0
#
#        CONTRIBUTING FACTOR VEHICLE 1 CONTRIBUTING FACTOR VEHICLE 2
# 850220                   Unspecified                   Unspecified
#        CONTRIBUTING FACTOR VEHICLE 3 CONTRIBUTING FACTOR VEHICLE 4  \
# 850220                           NaN                           NaN
#
#        CONTRIBUTING FACTOR VEHICLE 5  UNIQUE KEY VEHICLE TYPE CODE 1  \
# 850220                           NaN      183929   PASSENGER VEHICLE
#
#        VEHICLE TYPE CODE 2 VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 850220                 BUS                 NaN                 NaN
#
#        VEHICLE TYPE CODE 5
# 850220                 NaN

# %%
display(rev_colli[rev_colli['NUMBER OF PERSONS KILLED']==5].iloc[:,0:10])
display(rev_colli[rev_colli['NUMBER OF PERSONS KILLED']==5].iloc[:,10:20])
display(rev_colli[rev_colli['NUMBER OF PERSONS KILLED']==5].iloc[:,20:29])
# Out:
#                DATE  TIME BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 1077587  07/22/2012  3:20  QUEENS    11418  40.697204 -73.813334
#
#                           LOCATION                    ON STREET NAME  \
# 1077587  (40.6972045, -73.8133341)  94 AVENUE
#
#                         CROSS STREET NAME OFF STREET NAME
# 1077587  VAN WYCK EXPRESSWAY                          NaN
#          NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 1077587                          3                         5
#
#          NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# 1077587                              0                             0
#
#          NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# 1077587                          0                         0
#
#          NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  \
# 1077587                           3                          5
#
#         CONTRIBUTING FACTOR VEHICLE 1 CONTRIBUTING FACTOR VEHICLE 2
# 1077587   Traffic Control Disregarded                           NaN
#         CONTRIBUTING FACTOR VEHICLE 3 CONTRIBUTING FACTOR VEHICLE 4  \
# 1077587                           NaN                           NaN
#
#         CONTRIBUTING FACTOR VEHICLE 5  UNIQUE KEY  \
# 1077587                           NaN      208863
#
#                    VEHICLE TYPE CODE 1 VEHICLE TYPE CODE 2  \
# 1077587  SPORT UTILITY / STATION WAGON                 NaN
#
#         VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 1077587                 NaN                 NaN                 NaN

# %%
display(rev_colli[rev_colli['NUMBER OF PEDESTRIANS INJURED']==28].iloc[:,0:10])
display(rev_colli[rev_colli['NUMBER OF PEDESTRIANS INJURED']==28].iloc[:,10:20])
display(rev_colli[rev_colli['NUMBER OF PEDESTRIANS INJURED']==28].iloc[:,20:29])
# Out:
#              DATE   TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 51357  05/18/2017  11:54  MANHATTAN    10036  40.756035  -73.98695
#
#                      LOCATION                    ON STREET NAME  \
# 51357  (40.756035, -73.98695)  7 AVENUE
#
#       CROSS STREET NAME OFF STREET NAME
# 51357    WEST 42 STREET             NaN
#        NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 51357                         28                         1
#
#        NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# 51357                             28                             1
#
#        NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# 51357                          0                         0
#
#        NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  \
# 51357                           0                          0
#
#       CONTRIBUTING FACTOR VEHICLE 1 CONTRIBUTING FACTOR VEHICLE 2
# 51357               Drugs (Illegal)                           NaN
#       CONTRIBUTING FACTOR VEHICLE 3 CONTRIBUTING FACTOR VEHICLE 4  \
# 51357                           NaN                           NaN
#
#       CONTRIBUTING FACTOR VEHICLE 5  UNIQUE KEY VEHICLE TYPE CODE 1  \
# 51357                           NaN     3673559   PASSENGER VEHICLE
#
#       VEHICLE TYPE CODE 2 VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 51357                 NaN                 NaN                 NaN
#
#       VEHICLE TYPE CODE 5
# 51357                 NaN
